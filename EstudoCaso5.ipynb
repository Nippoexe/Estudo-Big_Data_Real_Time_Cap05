# %% [markdown]
# # <font color='blue'>Data Science Academy</font>
# # <font color='blue'>Big Data Real-Time Analytics com Python e Spark</font>
#
# ## <font color='blue'>Estudo de Caso 5</font>
#
# ## <font color='blue'>Pré-Processamento de Dados Para E-Commerce Analytics</font>

# %% [markdown]
# Obs: Estaremos trabalhando em um grande projeto de Ciência de Dados distribuído em 3 capítulos:
#
# - Análise Exploratória de Dados
#     - EDA Parte 1
#     - EDA Parte 2
# - Engenharia de Atributos
# - **Pré-Processamento de Dados**

# %% [markdown]
# O objetivo do Pré-processamento é deixar os dados no formato ideal para a próxima etapa dentro de um projeto de Ciência de Dados. Normalmente o Pré-processamento é a última etapa antes de treinar um modelo de Machine Learning.
#
# Algumas técnicas de Pré-processamento devem ser aplicadas exclusivamente nos dados de treino (isso será explicado durante as aulas). Como não faremos Machine Learning neste Estudo de Caso, aplicaremos todas as técnicas estudadas em todo o conjunto de dados. Nosso foco será estudar as técnicas.

# %% [markdown]
# ![title](imagens/EstudoCaso5.png)

# %%
# Versão da Linguagem Python
from platform import python_version
print('Versão da Linguagem Python Usada Neste Jupyter Notebook:', python_version())
# Out:
# Versão da Linguagem Python Usada Neste Jupyter Notebook: 3.10.0

# %%
# Para atualizar um pacote, execute o comando abaixo no terminal ou prompt de comando:
# %pip install -U sklearn

# Para instalar a versão exata de um pacote, execute o comando abaixo no terminal ou prompt de comando:
#!pip install nome_pacote==versão_desejada

# Depois de instalar ou atualizar o pacote, reinicie o jupyter notebook.

# Instala o pacote watermark. 
# Esse pacote é usado para gravar as versões de outros pacotes usados neste jupyter notebook.
#!pip install -q -U watermark
# Out:
# Requirement already satisfied: sklearn in c:\users\pichau\appdata\local\programs\python\python310\lib\site-packages (0.0)
# Collecting sklearn
#   Downloading sklearn-0.0.post12.tar.gz (2.6 kB)
#   Using cached sklearn-0.0.post11.tar.gz (3.6 kB)
#   Using cached sklearn-0.0.post10.tar.gz (3.6 kB)
#   Using cached sklearn-0.0.post9.tar.gz (3.6 kB)
#   Using cached sklearn-0.0.post7.tar.gz (3.6 kB)
#   Using cached sklearn-0.0.post5.tar.gz (3.7 kB)
#   Using cached sklearn-0.0.post4.tar.gz (3.6 kB)
#   Using cached sklearn-0.0.post1.tar.gz (3.6 kB)
# Requirement already satisfied: scikit-learn in c:\users\pichau\appdata\local\programs\python\python310\lib\site-packages (from sklearn) (1.3.2)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\pichau\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn->sklearn) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\pichau\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn->sklearn) (3.2.0)
# Requirement already satisfied: numpy<2.0,>=1.17.3 in c:\users\pichau\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn->sklearn) (1.25.0)
# Requirement already satisfied: scipy>=1.5.0 in c:\users\pichau\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn->sklearn) (1.11.3)
# Note: you may need to restart the kernel to use updated packages.
#     ERROR: Command errored out with exit status 1:
#      command: 'c:\Users\PICHAU\AppData\Local\Programs\Python\Python310\python.exe' -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\PICHAU\\AppData\\Local\\Temp\\pip-install-1f4658um\\sklearn_a8dfedd012d9413aa766170e166e5014\\setup.py'"'"'; __file__='"'"'C:\\Users\\PICHAU\\AppData\\Local\\Temp\\pip-install-1f4658um\\sklearn_a8dfedd012d9413aa766170e166e5014\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\PICHAU\AppData\Local\Temp\pip-pip-egg-info-6hncsub4'
#          cwd: C:\Users\PICHAU\AppData\Local\Temp\pip-install-1f4658um\sklearn_a8dfedd012d9413aa766170e166e5014\
#     Complete output (15 lines):
#     The 'sklearn' PyPI package is deprecated, use 'scikit-learn'
#     rather than 'sklearn' for pip commands.
#
#     Here is how to fix this error in the main use cases:
#     - use 'pip install scikit-learn' rather than 'pip install sklearn'
#     - replace 'sklearn' by 'scikit-learn' in your pip requirements files
#       (requirements.txt, setup.py, setup.cfg, Pipfile, etc ...)
#     - if the 'sklearn' package is used by one of your dependencies,
#       it would be great if you take some time to track which package uses
#       'sklearn' instead of 'scikit-learn' and report it to their issue tracker
#     - as a last resort, set the environment variable
#       SKLEARN_ALLOW_DEPRECATED_SKLEARN_PACKAGE_INSTALL=True to avoid this error
#
#     More information is available at
#     https://github.com/scikit-learn/sklearn-pypi-package
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/46/1c/395a83ee7b2d2ad7a05b453872053d41449564477c81dc356f720b16eac4/sklearn-0.0.post12.tar.gz#sha256=54cff9e20839b7b202321178228af4d9388bedf78425d9299fd9ee170d68802e (from https://pypi.org/simple/sklearn/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#     ERROR: Command errored out with exit status 1:
#      command: 'c:\Users\PICHAU\AppData\Local\Programs\Python\Python310\python.exe' -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\PICHAU\\AppData\\Local\\Temp\\pip-install-1f4658um\\sklearn_d1dfdea869954e25824ab9114083e04d\\setup.py'"'"'; __file__='"'"'C:\\Users\\PICHAU\\AppData\\Local\\Temp\\pip-install-1f4658um\\sklearn_d1dfdea869954e25824ab9114083e04d\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\PICHAU\AppData\Local\Temp\pip-pip-egg-info-i8l9p8zm'
#          cwd: C:\Users\PICHAU\AppData\Local\Temp\pip-install-1f4658um\sklearn_d1dfdea869954e25824ab9114083e04d\
#     Complete output (18 lines):
#     The 'sklearn' PyPI package is deprecated, use 'scikit-learn'
#     rather than 'sklearn' for pip commands.
#
#     Here is how to fix this error in the main use cases:
#     - use 'pip install scikit-learn' rather than 'pip install sklearn'
#     - replace 'sklearn' by 'scikit-learn' in your pip requirements files
#       (requirements.txt, setup.py, setup.cfg, Pipfile, etc ...)
#     - if the 'sklearn' package is used by one of your dependencies,
#       it would be great if you take some time to track which package uses
#       'sklearn' instead of 'scikit-learn' and report it to their issue tracker
#     - as a last resort, set the environment variable
#       SKLEARN_ALLOW_DEPRECATED_SKLEARN_PACKAGE_INSTALL=True to avoid this error
#
#     More information is available at
#     https://github.com/scikit-learn/sklearn-pypi-package
#
#     If the previous advice does not cover your use case, feel free to report it at
#     https://github.com/scikit-learn/sklearn-pypi-package/issues/new
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/a4/0b/d1c703256cf293be77b7db44dbef62251fe02a97d0bef981f7120b0b0c0f/sklearn-0.0.post11.tar.gz#sha256=af035c4f0b970b7fc2d3856079aa1aa1032df3d7f65048a9d87114abf13c4629 (from https://pypi.org/simple/sklearn/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#     ERROR: Command errored out with exit status 1:
#      command: 'c:\Users\PICHAU\AppData\Local\Programs\Python\Python310\python.exe' -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\PICHAU\\AppData\\Local\\Temp\\pip-install-1f4658um\\sklearn_473068f439ac489198381f75c926ceee\\setup.py'"'"'; __file__='"'"'C:\\Users\\PICHAU\\AppData\\Local\\Temp\\pip-install-1f4658um\\sklearn_473068f439ac489198381f75c926ceee\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\PICHAU\AppData\Local\Temp\pip-pip-egg-info-waxrvc8l'
#          cwd: C:\Users\PICHAU\AppData\Local\Temp\pip-install-1f4658um\sklearn_473068f439ac489198381f75c926ceee\
#     Complete output (18 lines):
#     The 'sklearn' PyPI package is deprecated, use 'scikit-learn'
#     rather than 'sklearn' for pip commands.
#
#     Here is how to fix this error in the main use cases:
#     - use 'pip install scikit-learn' rather than 'pip install sklearn'
#     - replace 'sklearn' by 'scikit-learn' in your pip requirements files
#       (requirements.txt, setup.py, setup.cfg, Pipfile, etc ...)
#     - if the 'sklearn' package is used by one of your dependencies,
#       it would be great if you take some time to track which package uses
#       'sklearn' instead of 'scikit-learn' and report it to their issue tracker
#     - as a last resort, set the environment variable
#       SKLEARN_ALLOW_DEPRECATED_SKLEARN_PACKAGE_INSTALL=True to avoid this error
#
#     More information is available at
#     https://github.com/scikit-learn/sklearn-pypi-package
#
#     If the previous advice does not cover your use case, feel free to report it at
#     https://github.com/scikit-learn/sklearn-pypi-package/issues/new
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/b9/0e/b2a4cfaa9e12b9ca4c71507bc26d2c99d75de172c0088c9835a98cf146ff/sklearn-0.0.post10.tar.gz#sha256=d4cd5a2e64b3caaf82cd5e33c46884dfeec5ebf991710d9faeb4fe81cadb3ba6 (from https://pypi.org/simple/sklearn/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#     ERROR: Command errored out with exit status 1:
#      command: 'c:\Users\PICHAU\AppData\Local\Programs\Python\Python310\python.exe' -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\PICHAU\\AppData\\Local\\Temp\\pip-install-1f4658um\\sklearn_da81678ea9104757bf9a73c3287e7682\\setup.py'"'"'; __file__='"'"'C:\\Users\\PICHAU\\AppData\\Local\\Temp\\pip-install-1f4658um\\sklearn_da81678ea9104757bf9a73c3287e7682\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\PICHAU\AppData\Local\Temp\pip-pip-egg-info-j9s8zu7z'
#          cwd: C:\Users\PICHAU\AppData\Local\Temp\pip-install-1f4658um\sklearn_da81678ea9104757bf9a73c3287e7682\
#     Complete output (18 lines):
#     The 'sklearn' PyPI package is deprecated, use 'scikit-learn'
#     rather than 'sklearn' for pip commands.
#
#     Here is how to fix this error in the main use cases:
#     - use 'pip install scikit-learn' rather than 'pip install sklearn'
#     - replace 'sklearn' by 'scikit-learn' in your pip requirements files
#       (requirements.txt, setup.py, setup.cfg, Pipfile, etc ...)
#     - if the 'sklearn' package is used by one of your dependencies,
#       it would be great if you take some time to track which package uses
#       'sklearn' instead of 'scikit-learn' and report it to their issue tracker
#     - as a last resort, set the environment variable
#       SKLEARN_ALLOW_DEPRECATED_SKLEARN_PACKAGE_INSTALL=True to avoid this error
#
#     More information is available at
#     https://github.com/scikit-learn/sklearn-pypi-package
#
#     If the previous advice does not cover your use case, feel free to report it at
#     https://github.com/scikit-learn/sklearn-pypi-package/issues/new
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/28/86/207a003339023247fef1bb5bc9f5093140d17294b2f6d15bfcd4885e469e/sklearn-0.0.post9.tar.gz#sha256=1ff5864cf30489ee48a014fe8f4320d7bb59592392a4ef52ae9d7a37942615ac (from https://pypi.org/simple/sklearn/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#     ERROR: Command errored out with exit status 1:
#      command: 'c:\Users\PICHAU\AppData\Local\Programs\Python\Python310\python.exe' -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\PICHAU\\AppData\\Local\\Temp\\pip-install-1f4658um\\sklearn_84326b5f63b040099e38011c62474a5e\\setup.py'"'"'; __file__='"'"'C:\\Users\\PICHAU\\AppData\\Local\\Temp\\pip-install-1f4658um\\sklearn_84326b5f63b040099e38011c62474a5e\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\PICHAU\AppData\Local\Temp\pip-pip-egg-info-4r4w36ud'
#          cwd: C:\Users\PICHAU\AppData\Local\Temp\pip-install-1f4658um\sklearn_84326b5f63b040099e38011c62474a5e\
#     Complete output (18 lines):
#     The 'sklearn' PyPI package is deprecated, use 'scikit-learn'
#     rather than 'sklearn' for pip commands.
#
#     Here is how to fix this error in the main use cases:
#     - use 'pip install scikit-learn' rather than 'pip install sklearn'
#     - replace 'sklearn' by 'scikit-learn' in your pip requirements files
#       (requirements.txt, setup.py, setup.cfg, Pipfile, etc ...)
#     - if the 'sklearn' package is used by one of your dependencies,
#       it would be great if you take some time to track which package uses
#       'sklearn' instead of 'scikit-learn' and report it to their issue tracker
#     - as a last resort, set the environment variable
#       SKLEARN_ALLOW_DEPRECATED_SKLEARN_PACKAGE_INSTALL=True to avoid this error
#
#     More information is available at
#     https://github.com/scikit-learn/sklearn-pypi-package
#
#     If the previous advice does not cover your use case, feel free to report it at
#     https://github.com/scikit-learn/sklearn-pypi-package/issues/new
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/70/ce/81aa643f3c43488c4a1e417e45f696a61e7ac82b57190fad3c310df2c07b/sklearn-0.0.post7.tar.gz#sha256=1c89020b364fdc3aa2839e0ae34e8f0b406669e4b5c2359dda3ac398f9c76874 (from https://pypi.org/simple/sklearn/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#     ERROR: Command errored out with exit status 1:
#      command: 'c:\Users\PICHAU\AppData\Local\Programs\Python\Python310\python.exe' -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\PICHAU\\AppData\\Local\\Temp\\pip-install-1f4658um\\sklearn_ab757aa083e64fd98f65f2b39d06967f\\setup.py'"'"'; __file__='"'"'C:\\Users\\PICHAU\\AppData\\Local\\Temp\\pip-install-1f4658um\\sklearn_ab757aa083e64fd98f65f2b39d06967f\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\PICHAU\AppData\Local\Temp\pip-pip-egg-info-ia9iog5i'
#          cwd: C:\Users\PICHAU\AppData\Local\Temp\pip-install-1f4658um\sklearn_ab757aa083e64fd98f65f2b39d06967f\
#     Complete output (18 lines):
#     The 'sklearn' PyPI package is deprecated, use 'scikit-learn'
#     rather than 'sklearn' for pip commands.
#
#     Here is how to fix this error in the main use cases:
#     - use 'pip install scikit-learn' rather than 'pip install sklearn'
#     - replace 'sklearn' by 'scikit-learn' in your pip requirements files
#       (requirements.txt, setup.py, setup.cfg, Pipfile, etc ...)
#     - if the 'sklearn' package is used by one of your dependencies,
#       it would be great if you take some time to track which package uses
#       'sklearn' instead of 'scikit-learn' and report it to their issue tracker
#     - as a last resort, set the environment variable
#       SKLEARN_ALLOW_DEPRECATED_SKLEARN_PACKAGE_INSTALL=True to avoid this error
#
#     More information is available at
#     https://github.com/scikit-learn/sklearn-pypi-package
#
#     If the previous advice does not cover your use case, feel free to report it at
#     https://github.com/scikit-learn/sklearn-pypi-package/issues/new
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/7a/93/e0e1b1e98f39dfca7ec9795cb46f6e09e88a2fd5d4a28e4b3d1f618a2aec/sklearn-0.0.post5.tar.gz#sha256=7377c714a03a79bbe9196f435db931fd2a6fa8c68514da7ed3a251fd08c52e2c (from https://pypi.org/simple/sklearn/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#     ERROR: Command errored out with exit status 1:
#      command: 'c:\Users\PICHAU\AppData\Local\Programs\Python\Python310\python.exe' -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\PICHAU\\AppData\\Local\\Temp\\pip-install-1f4658um\\sklearn_66c8ac5bc9c240c39466fe109e669281\\setup.py'"'"'; __file__='"'"'C:\\Users\\PICHAU\\AppData\\Local\\Temp\\pip-install-1f4658um\\sklearn_66c8ac5bc9c240c39466fe109e669281\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\PICHAU\AppData\Local\Temp\pip-pip-egg-info-yox2kso0'
#          cwd: C:\Users\PICHAU\AppData\Local\Temp\pip-install-1f4658um\sklearn_66c8ac5bc9c240c39466fe109e669281\
#     Complete output (18 lines):
#     The 'sklearn' PyPI package is deprecated, use 'scikit-learn'
#     rather than 'sklearn' for pip commands.
#
#     Here is how to fix this error in the main use cases:
#     - use 'pip install scikit-learn' rather than 'pip install sklearn'
#     - replace 'sklearn' by 'scikit-learn' in your pip requirements files
#       (requirements.txt, setup.py, setup.cfg, Pipfile, etc ...)
#     - if the 'sklearn' package is used by one of your dependencies,
#       it would be great if you take some time to track which package uses
#       'sklearn' instead of 'scikit-learn' and report it to their issue tracker
#     - as a last resort, set the environment variable
#       SKLEARN_ALLOW_DEPRECATED_SKLEARN_PACKAGE_INSTALL=True to avoid this error
#
#     More information is available at
#     https://github.com/scikit-learn/sklearn-pypi-package
#
#     If the previous advice does not cover your use case, feel free to report it at
#     https://github.com/scikit-learn/sklearn-pypi-package/issues/new
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/99/b2/165110013aa66fae6fc13918ad0e9de4801e5f1691d371bf8b63328037e6/sklearn-0.0.post4.tar.gz#sha256=0e81ec9c32d4bb418e7be8f1ec1027d174975502dc84cbc4f4564b4cba31e674 (from https://pypi.org/simple/sklearn/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#     ERROR: Command errored out with exit status 1:
#      command: 'c:\Users\PICHAU\AppData\Local\Programs\Python\Python310\python.exe' -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\PICHAU\\AppData\\Local\\Temp\\pip-install-1f4658um\\sklearn_22ba6a0eba28494e9fa6d872a2e4fe15\\setup.py'"'"'; __file__='"'"'C:\\Users\\PICHAU\\AppData\\Local\\Temp\\pip-install-1f4658um\\sklearn_22ba6a0eba28494e9fa6d872a2e4fe15\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\PICHAU\AppData\Local\Temp\pip-pip-egg-info-srrt32h1'
#          cwd: C:\Users\PICHAU\AppData\Local\Temp\pip-install-1f4658um\sklearn_22ba6a0eba28494e9fa6d872a2e4fe15\
#     Complete output (18 lines):
#     The 'sklearn' PyPI package is deprecated, use 'scikit-learn'
#     rather than 'sklearn' for pip commands.
#
#     Here is how to fix this error in the main use cases:
#     - use 'pip install scikit-learn' rather than 'pip install sklearn'
#     - replace 'sklearn' by 'scikit-learn' in your pip requirements files
#       (requirements.txt, setup.py, setup.cfg, Pipfile, etc ...)
#     - if the 'sklearn' package is used by one of your dependencies,
#       it would be great if you take some time to track which package uses
#       'sklearn' instead of 'scikit-learn' and report it to their issue tracker
#     - as a last resort, set the environment variable
#       SKLEARN_ALLOW_DEPRECATED_SKLEARN_PACKAGE_INSTALL=True to avoid this error
#
#     More information is available at
#     https://github.com/scikit-learn/sklearn-pypi-package
#
#     If the previous advice does not cover your use case, feel free to report it at
#     https://github.com/scikit-learn/sklearn-pypi-package/issues/new
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/db/1e/af4e9cded5093a92e60d4ae7149a02c7427661b2db66c8ea4d34b17864a2/sklearn-0.0.post1.tar.gz#sha256=76b9ed1623775168657b86b5fe966d45752e5c87f528de6240c38923b94147c5 (from https://pypi.org/simple/sklearn/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
# WARNING: You are using pip version 21.2.3; however, version 23.3.2 is available.
# You should consider upgrading via the 'c:\Users\PICHAU\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %%
# Imports
import sklearn
import numpy as np
import pandas as pd
from sklearn.preprocessing import LabelEncoder, MinMaxScaler, StandardScaler

# %%
# Versões dos pacotes usados neste jupyter notebook
# %reload_ext watermark
# %watermark -a "Data Science Academy" --iversions
# Out:
# Author: Data Science Academy
#
# numpy  : 1.25.0
# sklearn: 0.0
# pandas : 2.0.2

# %% [markdown]
# ## Carregando o Dataset (Gerado ao Final do Estudo de Caso 4)

# %%
# Carrega o dataset
file_path = "D:/FCDados/[02] - Big_Data_Real_Time_Analytics_com_Python_Spark/[06] - Pre_Processamento_Dados/[01] - InputData/"
df = pd.read_csv(file_path + 'df_eng.csv', index_col = 0)

# %%
df.shape
# Out:
# (10643, 16)

# %%
df.head()
# Out:
#    ID corredor_armazem modo_envio  numero_chamadas_cliente  avaliacao_cliente  \
# 0   1                D      Aviao                        4                  2
# 1   2                F      Aviao                        4                  5
# 2   3                A      Aviao                        2                  2
# 3   4                B      Aviao                        3                  3
# 4   5                C      Aviao                        2                  2
#
#    custo_produto  compras_anteriores prioridade_produto genero  desconto  \
# 0            177                   3              baixa      F        44
# 1            216                   2              baixa      M        59
# 2            183                   4              baixa      M        48
# 3            176                   4              media      M        10
# 4            184                   3              media      F        46
#
#    peso_gramas  entregue_no_prazo performance_prioridade_envio  \
# 0         1233                  1             Não Houve Atraso
# 1         3088                  1             Não Houve Atraso
# 2         3374                  1             Não Houve Atraso
# 3         1177                  1             Não Houve Atraso
# 4         2484                  1             Não Houve Atraso
#
#   performance_modo_envio            faixa_desconto  \
# 0       Não Houve Atraso   Desconto Acima da Media
# 1       Não Houve Atraso   Desconto Acima da Media
# 2       Não Houve Atraso   Desconto Acima da Media
# 3       Não Houve Atraso  Desconto Abaixo da Media
# 4       Não Houve Atraso   Desconto Acima da Media
#
#                       performance_faixa_desconto
# 0   Entrega no Prazo com Desconto Acima da Media
# 1   Entrega no Prazo com Desconto Acima da Media
# 2   Entrega no Prazo com Desconto Acima da Media
# 3  Entrega no Prazo com Desconto Abaixo da Media
# 4   Entrega no Prazo com Desconto Acima da Media

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10643 entries, 0 to 10999
# Data columns (total 16 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   ID                            10643 non-null  int64
#  1   corredor_armazem              10643 non-null  object
#  2   modo_envio                    10643 non-null  object
#  3   numero_chamadas_cliente       10643 non-null  int64
#  4   avaliacao_cliente             10643 non-null  int64
#  5   custo_produto                 10643 non-null  int64
#  6   compras_anteriores            10643 non-null  int64
#  7   prioridade_produto            10643 non-null  object
#  8   genero                        10643 non-null  object
#  9   desconto                      10643 non-null  int64
#  10  peso_gramas                   10643 non-null  int64
#  11  entregue_no_prazo             10643 non-null  int64
#  12  performance_prioridade_envio  10643 non-null  object
#  13  performance_modo_envio        10643 non-null  object
#  14  faixa_desconto                10643 non-null  object
#  15  performance_faixa_desconto    10643 non-null  object
# dtypes: int64(8), object(8)
# memory usage: 1.4+ MB

# %%
df.columns
# Out:
# Index(['ID', 'corredor_armazem', 'modo_envio', 'numero_chamadas_cliente',
#        'avaliacao_cliente', 'custo_produto', 'compras_anteriores',
#        'prioridade_produto', 'genero', 'desconto', 'peso_gramas',
#        'entregue_no_prazo', 'performance_prioridade_envio',
#        'performance_modo_envio', 'faixa_desconto',
#        'performance_faixa_desconto'],
#       dtype='object')

# %% [markdown]
# ## Label Encoding
#
# Leia o manual em pdf no Capítulo 6 com a definição de Label Encoding.

# %% [markdown]
# ### Método 1

# %%
# Variável categórica ordinal
df.prioridade_produto.value_counts()
# Out:
# prioridade_produto
# baixa    5174
# media    4587
# alta      882
# Name: count, dtype: int64

# %%
# Dicionário de mapeamento
dic_prioridade_produto = {'baixa' : 1, 'media' : 2, 'alta' : 0}

# %%
df['prioridade_produto'] = df['prioridade_produto'].map(dic_prioridade_produto)

# %%
df.prioridade_produto.value_counts()
# Out:
# prioridade_produto
# 1    5174
# 2    4587
# 0     882
# Name: count, dtype: int64

# %%
df.head()
# Out:
#    ID corredor_armazem modo_envio  numero_chamadas_cliente  avaliacao_cliente  \
# 0   1                D      Aviao                        4                  2
# 1   2                F      Aviao                        4                  5
# 2   3                A      Aviao                        2                  2
# 3   4                B      Aviao                        3                  3
# 4   5                C      Aviao                        2                  2
#
#    custo_produto  compras_anteriores  prioridade_produto genero  desconto  \
# 0            177                   3                   1      F        44
# 1            216                   2                   1      M        59
# 2            183                   4                   1      M        48
# 3            176                   4                   2      M        10
# 4            184                   3                   2      F        46
#
#    peso_gramas  entregue_no_prazo performance_prioridade_envio  \
# 0         1233                  1             Não Houve Atraso
# 1         3088                  1             Não Houve Atraso
# 2         3374                  1             Não Houve Atraso
# 3         1177                  1             Não Houve Atraso
# 4         2484                  1             Não Houve Atraso
#
#   performance_modo_envio            faixa_desconto  \
# 0       Não Houve Atraso   Desconto Acima da Media
# 1       Não Houve Atraso   Desconto Acima da Media
# 2       Não Houve Atraso   Desconto Acima da Media
# 3       Não Houve Atraso  Desconto Abaixo da Media
# 4       Não Houve Atraso   Desconto Acima da Media
#
#                       performance_faixa_desconto
# 0   Entrega no Prazo com Desconto Acima da Media
# 1   Entrega no Prazo com Desconto Acima da Media
# 2   Entrega no Prazo com Desconto Acima da Media
# 3  Entrega no Prazo com Desconto Abaixo da Media
# 4   Entrega no Prazo com Desconto Acima da Media

# %%
# Variável categórica ordinal (passível de interpretação)
df.modo_envio.value_counts()
# Out:
# modo_envio
# Navio       7212
# Aviao       1728
# Caminhao    1703
# Name: count, dtype: int64

# %%
# Dicionário de mapeamento
dic_modo_envio = {'Navio' : 0, 'Aviao' : 1, 'Caminhao' : 2}

# %%
df['modo_envio'] = df['modo_envio'].map(dic_modo_envio)

# %%
df.modo_envio.value_counts()
# Out:
# modo_envio
# 0    7212
# 1    1728
# 2    1703
# Name: count, dtype: int64

# %%
df.head()
# Out:
#    ID corredor_armazem  modo_envio  numero_chamadas_cliente  \
# 0   1                D           1                        4
# 1   2                F           1                        4
# 2   3                A           1                        2
# 3   4                B           1                        3
# 4   5                C           1                        2
#
#    avaliacao_cliente  custo_produto  compras_anteriores  prioridade_produto  \
# 0                  2            177                   3                   1
# 1                  5            216                   2                   1
# 2                  2            183                   4                   1
# 3                  3            176                   4                   2
# 4                  2            184                   3                   2
#
#   genero  desconto  peso_gramas  entregue_no_prazo  \
# 0      F        44         1233                  1
# 1      M        59         3088                  1
# 2      M        48         3374                  1
# 3      M        10         1177                  1
# 4      F        46         2484                  1
#
#   performance_prioridade_envio performance_modo_envio  \
# 0             Não Houve Atraso       Não Houve Atraso
# 1             Não Houve Atraso       Não Houve Atraso
# 2             Não Houve Atraso       Não Houve Atraso
# 3             Não Houve Atraso       Não Houve Atraso
# 4             Não Houve Atraso       Não Houve Atraso
#
#              faixa_desconto                     performance_faixa_desconto
# 0   Desconto Acima da Media   Entrega no Prazo com Desconto Acima da Media
# 1   Desconto Acima da Media   Entrega no Prazo com Desconto Acima da Media
# 2   Desconto Acima da Media   Entrega no Prazo com Desconto Acima da Media
# 3  Desconto Abaixo da Media  Entrega no Prazo com Desconto Abaixo da Media
# 4   Desconto Acima da Media   Entrega no Prazo com Desconto Acima da Media

# %% [markdown]
# ### Método 2

# %%
# Variável categórica nominal
df.genero.value_counts()
# Out:
# genero
# F    5357
# M    5286
# Name: count, dtype: int64

# %%
# Cria o objeto encoder
le = LabelEncoder()

# %%
# Treina o objeto (normalmente fazemos isso somente com dados de treino)
le.fit(df.genero)
# Out:
# LabelEncoder()

# %%
list(le.classes_)
# Out:
# ['F', 'M']

# %%
# Aplicamos o objeto encoder treinado 
# (fazemos isso em dados de treino e teste e também em novos dados usados no modelo)
df.genero = le.transform(df.genero)

# %%
df.genero.value_counts()
# Out:
# genero
# 0    5357
# 1    5286
# Name: count, dtype: int64

# %% [markdown]
# ## One-Hot Encoding
#
# Leia o manual em pdf no Capítulo 6 com a definição de One-Hot Encoding.

# %% [markdown]
# ![title](imagens/one-hot-encoding.png)

# %%
df.head()
# Out:
#    ID corredor_armazem  modo_envio  numero_chamadas_cliente  \
# 0   1                D           1                        4
# 1   2                F           1                        4
# 2   3                A           1                        2
# 3   4                B           1                        3
# 4   5                C           1                        2
#
#    avaliacao_cliente  custo_produto  compras_anteriores  prioridade_produto  \
# 0                  2            177                   3                   1
# 1                  5            216                   2                   1
# 2                  2            183                   4                   1
# 3                  3            176                   4                   2
# 4                  2            184                   3                   2
#
#    genero  desconto  peso_gramas  entregue_no_prazo  \
# 0       0        44         1233                  1
# 1       1        59         3088                  1
# 2       1        48         3374                  1
# 3       1        10         1177                  1
# 4       0        46         2484                  1
#
#   performance_prioridade_envio performance_modo_envio  \
# 0             Não Houve Atraso       Não Houve Atraso
# 1             Não Houve Atraso       Não Houve Atraso
# 2             Não Houve Atraso       Não Houve Atraso
# 3             Não Houve Atraso       Não Houve Atraso
# 4             Não Houve Atraso       Não Houve Atraso
#
#              faixa_desconto                     performance_faixa_desconto
# 0   Desconto Acima da Media   Entrega no Prazo com Desconto Acima da Media
# 1   Desconto Acima da Media   Entrega no Prazo com Desconto Acima da Media
# 2   Desconto Acima da Media   Entrega no Prazo com Desconto Acima da Media
# 3  Desconto Abaixo da Media  Entrega no Prazo com Desconto Abaixo da Media
# 4   Desconto Acima da Media   Entrega no Prazo com Desconto Acima da Media

# %%
# Variável categórica nominal
df.corredor_armazem.value_counts()
# Out:
# corredor_armazem
# F    3539
# B    1778
# D    1777
# A    1777
# C    1772
# Name: count, dtype: int64

# %%
# Variável categórica nominal
df.performance_prioridade_envio.value_counts()
# Out:
# performance_prioridade_envio
# Não Houve Atraso       6282
# Atraso Tolerável       2134
# Atraso Problemático    1917
# Atraso Crítico          310
# Name: count, dtype: int64

# %%
# Variável categórica nominal
df.performance_modo_envio.value_counts()
# Out:
# performance_modo_envio
# Não Houve Atraso                               6282
# Atraso Tolerável na Entrega Por Navio          1453
# Atraso Problemático na Entrega Por Navio       1307
# Atraso Tolerável na Entrega Por Caminhao        350
# Atraso Tolerável na Entrega Por Aviao           331
# Atraso Problemático na Entrega Por Caminhao     310
# Atraso Problemático na Entrega Por Aviao        300
# Atraso Crítico na Entrega Por Navio             194
# Atraso Crítico na Entrega Por Aviao              65
# Atraso Crítico na Entrega Por Caminhao           51
# Name: count, dtype: int64

# %%
# Variável categórica nominal
df.faixa_desconto.value_counts()
# Out:
# faixa_desconto
# Desconto Abaixo da Media    8269
# Desconto Acima da Media     2374
# Name: count, dtype: int64

# %%
# Variável categórica nominal
df.performance_faixa_desconto.value_counts()
# Out:
# performance_faixa_desconto
# Atraso na Entrega com Desconto Abaixo da Media    4361
# Entrega no Prazo com Desconto Abaixo da Media     3908
# Entrega no Prazo com Desconto Acima da Media      2374
# Name: count, dtype: int64

# %%
# Aplicando One-Hot Encoding
for cat in ['corredor_armazem', 
            'performance_prioridade_envio', 
            'performance_modo_envio', 
            'faixa_desconto', 
            'performance_faixa_desconto']:
    onehots = pd.get_dummies(df[cat], prefix = cat)
    df = df.join(onehots)

# %%
df.columns
# Out:
# Index(['ID', 'corredor_armazem', 'modo_envio', 'numero_chamadas_cliente',
#        'avaliacao_cliente', 'custo_produto', 'compras_anteriores',
#        'prioridade_produto', 'genero', 'desconto', 'peso_gramas',
#        'entregue_no_prazo', 'performance_prioridade_envio',
#        'performance_modo_envio', 'faixa_desconto',
#        'performance_faixa_desconto', 'corredor_armazem_A',
#        'corredor_armazem_B', 'corredor_armazem_C', 'corredor_armazem_D',
#        'corredor_armazem_F', 'performance_prioridade_envio_Atraso Crítico',
#        'performance_prioridade_envio_Atraso Problemático',
#        'performance_prioridade_envio_Atraso Tolerável',
#        'performance_prioridade_envio_Não Houve Atraso',
#        'performance_modo_envio_Atraso Crítico na Entrega Por Aviao',
#        'performance_modo_envio_Atraso Crítico na Entrega Por Caminhao',
#        'performance_modo_envio_Atraso Crítico na Entrega Por Navio',
#        'performance_modo_envio_Atraso Problemático na Entrega Por Aviao',
#        'performance_modo_envio_Atraso Problemático na Entrega Por Caminhao',
#        'performance_modo_envio_Atraso Problemático na Entrega Por Navio',
#        'performance_modo_envio_Atraso Tolerável na Entrega Por Aviao',
#        'performance_modo_envio_Atraso Tolerável na Entrega Por Caminhao',
#        'performance_modo_envio_Atraso Tolerável na Entrega Por Navio',
#        'performance_modo_envio_Não Houve Atraso',
#        'faixa_desconto_Desconto Abaixo da Media',
#        'faixa_desconto_Desconto Acima da Media',
#        'performance_faixa_desconto_Atraso na Entrega com Desconto Abaixo da Media',
#        'performance_faixa_desconto_Entrega no Prazo com Desconto Abaixo da Media',
#        'performance_faixa_desconto_Entrega no Prazo com Desconto Acima da Media'],
#       dtype='object')

# %%
df.head()
# Out:
#    ID corredor_armazem  modo_envio  numero_chamadas_cliente  \
# 0   1                D           1                        4
# 1   2                F           1                        4
# 2   3                A           1                        2
# 3   4                B           1                        3
# 4   5                C           1                        2
#
#    avaliacao_cliente  custo_produto  compras_anteriores  prioridade_produto  \
# 0                  2            177                   3                   1
# 1                  5            216                   2                   1
# 2                  2            183                   4                   1
# 3                  3            176                   4                   2
# 4                  2            184                   3                   2
#
#    genero  desconto  ...  \
# 0       0        44  ...
# 1       1        59  ...
# 2       1        48  ...
# 3       1        10  ...
# 4       0        46  ...
#
#    performance_modo_envio_Atraso Problemático na Entrega Por Navio  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    performance_modo_envio_Atraso Tolerável na Entrega Por Aviao  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#   performance_modo_envio_Atraso Tolerável na Entrega Por Caminhao  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#   performance_modo_envio_Atraso Tolerável na Entrega Por Navio  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#   performance_modo_envio_Não Houve Atraso  \
# 0                                    True
# 1                                    True
# 2                                    True
# 3                                    True
# 4                                    True
#
#   faixa_desconto_Desconto Abaixo da Media  \
# 0                                   False
# 1                                   False
# 2                                   False
# 3                                    True
# 4                                   False
#
#    faixa_desconto_Desconto Acima da Media  \
# 0                                    True
# 1                                    True
# 2                                    True
# 3                                   False
# 4                                    True
#
#    performance_faixa_desconto_Atraso na Entrega com Desconto Abaixo da Media  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    performance_faixa_desconto_Entrega no Prazo com Desconto Abaixo da Media  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                               True
# 4                                              False
#
#    performance_faixa_desconto_Entrega no Prazo com Desconto Acima da Media
# 0                                               True
# 1                                               True
# 2                                               True
# 3                                              False
# 4                                               True
#
# [5 rows x 40 columns]

# %%
# Não precisaremos mais das colunas originais após aplicar One-Hot Encoding
df = df.drop(columns = ['corredor_armazem', 
                        'performance_prioridade_envio', 
                        'performance_modo_envio', 
                        'faixa_desconto', 
                        'performance_faixa_desconto'])

# %%
# Podemos remover a coluna ID
df = df.drop(columns = ['ID'])

# %%
df.head()
# Out:
#    modo_envio  numero_chamadas_cliente  avaliacao_cliente  custo_produto  \
# 0           1                        4                  2            177
# 1           1                        4                  5            216
# 2           1                        2                  2            183
# 3           1                        3                  3            176
# 4           1                        2                  2            184
#
#    compras_anteriores  prioridade_produto  genero  desconto  peso_gramas  \
# 0                   3                   1       0        44         1233
# 1                   2                   1       1        59         3088
# 2                   4                   1       1        48         3374
# 3                   4                   2       1        10         1177
# 4                   3                   2       0        46         2484
#
#    entregue_no_prazo  ...  \
# 0                  1  ...
# 1                  1  ...
# 2                  1  ...
# 3                  1  ...
# 4                  1  ...
#
#    performance_modo_envio_Atraso Problemático na Entrega Por Navio  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    performance_modo_envio_Atraso Tolerável na Entrega Por Aviao  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    performance_modo_envio_Atraso Tolerável na Entrega Por Caminhao  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    performance_modo_envio_Atraso Tolerável na Entrega Por Navio  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    performance_modo_envio_Não Houve Atraso  \
# 0                                     True
# 1                                     True
# 2                                     True
# 3                                     True
# 4                                     True
#
#    faixa_desconto_Desconto Abaixo da Media  \
# 0                                    False
# 1                                    False
# 2                                    False
# 3                                     True
# 4                                    False
#
#    faixa_desconto_Desconto Acima da Media  \
# 0                                    True
# 1                                    True
# 2                                    True
# 3                                   False
# 4                                    True
#
#    performance_faixa_desconto_Atraso na Entrega com Desconto Abaixo da Media  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    performance_faixa_desconto_Entrega no Prazo com Desconto Abaixo da Media  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                               True
# 4                                              False
#
#    performance_faixa_desconto_Entrega no Prazo com Desconto Acima da Media
# 0                                               True
# 1                                               True
# 2                                               True
# 3                                              False
# 4                                               True
#
# [5 rows x 34 columns]

# %% [markdown]
# ## Fature Scaling
#
# Leia os manuais em pdf no Capítulo 6. Abaixo um resumo:
#
# - O dimensionamento de recursos (Fature Scaling) consiste em transformar o valor dos recursos em uma faixa semelhante, para que os algoritmos de aprendizado de máquina se comportem melhor, resultando em modelos ideais.
#
# - Padronização e normalização são duas técnicas mais comuns para dimensionamento de recursos.
#
# - A normalização é transformar os valores dos recursos para que caiam dentro dos intervalos limitados (min e max).
#
# - A padronização é transformar os valores de recursos para cair em torno da média como 0 com desvio padrão como 1.
#
# - A padronização mantém informações úteis sobre valores discrepantes e torna o algoritmo menos sensível a eles em contraste com o dimensionamento mínimo-máximo.
#
# - A classe MinMaxScaler() de sklearn.preprocessing é usada para normalização de recursos.
#
# - A classe StandardScaler() de sklearn.preprocessing é usada para padronização de recursos.

# %%
df.head()
# Out:
#    modo_envio  numero_chamadas_cliente  avaliacao_cliente  custo_produto  \
# 0           1                        4                  2            177
# 1           1                        4                  5            216
# 2           1                        2                  2            183
# 3           1                        3                  3            176
# 4           1                        2                  2            184
#
#    compras_anteriores  prioridade_produto  genero  desconto  peso_gramas  \
# 0                   3                   1       0        44         1233
# 1                   2                   1       1        59         3088
# 2                   4                   1       1        48         3374
# 3                   4                   2       1        10         1177
# 4                   3                   2       0        46         2484
#
#    entregue_no_prazo  ...  \
# 0                  1  ...
# 1                  1  ...
# 2                  1  ...
# 3                  1  ...
# 4                  1  ...
#
#    performance_modo_envio_Atraso Problemático na Entrega Por Navio  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    performance_modo_envio_Atraso Tolerável na Entrega Por Aviao  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    performance_modo_envio_Atraso Tolerável na Entrega Por Caminhao  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    performance_modo_envio_Atraso Tolerável na Entrega Por Navio  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    performance_modo_envio_Não Houve Atraso  \
# 0                                     True
# 1                                     True
# 2                                     True
# 3                                     True
# 4                                     True
#
#    faixa_desconto_Desconto Abaixo da Media  \
# 0                                    False
# 1                                    False
# 2                                    False
# 3                                     True
# 4                                    False
#
#    faixa_desconto_Desconto Acima da Media  \
# 0                                    True
# 1                                    True
# 2                                    True
# 3                                   False
# 4                                    True
#
#    performance_faixa_desconto_Atraso na Entrega com Desconto Abaixo da Media  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    performance_faixa_desconto_Entrega no Prazo com Desconto Abaixo da Media  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                               True
# 4                                              False
#
#    performance_faixa_desconto_Entrega no Prazo com Desconto Acima da Media
# 0                                               True
# 1                                               True
# 2                                               True
# 3                                              False
# 4                                               True
#
# [5 rows x 34 columns]

# %%
df.columns
# Out:
# Index(['modo_envio', 'numero_chamadas_cliente', 'avaliacao_cliente',
#        'custo_produto', 'compras_anteriores', 'prioridade_produto', 'genero',
#        'desconto', 'peso_gramas', 'entregue_no_prazo', 'corredor_armazem_A',
#        'corredor_armazem_B', 'corredor_armazem_C', 'corredor_armazem_D',
#        'corredor_armazem_F', 'performance_prioridade_envio_Atraso Crítico',
#        'performance_prioridade_envio_Atraso Problemático',
#        'performance_prioridade_envio_Atraso Tolerável',
#        'performance_prioridade_envio_Não Houve Atraso',
#        'performance_modo_envio_Atraso Crítico na Entrega Por Aviao',
#        'performance_modo_envio_Atraso Crítico na Entrega Por Caminhao',
#        'performance_modo_envio_Atraso Crítico na Entrega Por Navio',
#        'performance_modo_envio_Atraso Problemático na Entrega Por Aviao',
#        'performance_modo_envio_Atraso Problemático na Entrega Por Caminhao',
#        'performance_modo_envio_Atraso Problemático na Entrega Por Navio',
#        'performance_modo_envio_Atraso Tolerável na Entrega Por Aviao',
#        'performance_modo_envio_Atraso Tolerável na Entrega Por Caminhao',
#        'performance_modo_envio_Atraso Tolerável na Entrega Por Navio',
#        'performance_modo_envio_Não Houve Atraso',
#        'faixa_desconto_Desconto Abaixo da Media',
#        'faixa_desconto_Desconto Acima da Media',
#        'performance_faixa_desconto_Atraso na Entrega com Desconto Abaixo da Media',
#        'performance_faixa_desconto_Entrega no Prazo com Desconto Abaixo da Media',
#        'performance_faixa_desconto_Entrega no Prazo com Desconto Acima da Media'],
#       dtype='object')

# %% [markdown]
# **ATENÇÃO**: No caso de normalizar o conjunto de dados de treinamento e teste, o estimador MinMaxScaler() terá o fit() no conjunto de dados de treinamento e o mesmo estimador será usado para transformar o conjunto de dados de treinamento e teste. O mesmo estimador também deve ser usado em novos dados ao fazer previsões com o modelo.

# %%
df.peso_gramas.sample(5)
# Out:
# 8712    4879
# 7535    5566
# 5694    5116
# 7845    4831
# 5493    5368
# Name: peso_gramas, dtype: int64

# %%
df['peso_gramas'] = MinMaxScaler().fit_transform(df['peso_gramas'].values.reshape(len(df), 1))

# %%
df.peso_gramas.sample(5)
# Out:
# 1300    0.304894
# 5140    0.661359
# 4811    0.058729
# 9341    0.605259
# 8940    0.636231
# Name: peso_gramas, dtype: float64

# %%
df.custo_produto.sample(5)
# Out:
# 8882    251
# 2614    253
# 7946    255
# 4026    166
# 170     185
# Name: custo_produto, dtype: int64

# %%
df['custo_produto'] = MinMaxScaler().fit_transform(df['custo_produto'].values.reshape(len(df), 1))

# %%
df.custo_produto.sample(10)
# Out:
# 644      0.116822
# 5637     0.556075
# 2946     0.224299
# 10353    0.467290
# 10291    0.233645
# 10465    0.742991
# 1047     0.752336
# 475      0.172897
# 2225     0.238318
# 8095     0.794393
# Name: custo_produto, dtype: float64

# %% [markdown]
# **ATENÇÃO**: No caso de padronizar o conjunto de dados de treinamento e teste, o estimador StandardScaler() terá o fit() no conjunto de dados de treinamento e o mesmo estimador será usado para transformar o conjunto de dados de treinamento e teste. O mesmo estimador também deve ser usado em novos dados ao fazer previsões com o modelo.

# %%
df['desconto'] = StandardScaler().fit_transform(df['desconto'].values.reshape(len(df), 1))

# %%
df.desconto.sample(10)
# Out:
# 307     -0.235340
# 527      0.631832
# 7324    -0.368751
# 10603   -0.635573
# 10255   -0.568868
# 8491    -0.435457
# 118     -0.502162
# 587     -0.568868
# 10473   -0.368751
# 8707    -0.768984
# Name: desconto, dtype: float64

# %%
df['numero_chamadas_cliente'] = StandardScaler().fit_transform(df['numero_chamadas_cliente'].values.reshape(len(df), 
                                                                                                            1))

# %%
df.numero_chamadas_cliente.sample(10)
# Out:
# 1815    -0.930527
# 1245    -0.057348
# 10964    0.815832
# 6957     0.815832
# 5081     0.815832
# 7387    -0.057348
# 9116    -0.930527
# 10861   -0.057348
# 1723     0.815832
# 2461    -0.930527
# Name: numero_chamadas_cliente, dtype: float64

# %%
df['avaliacao_cliente'] = StandardScaler().fit_transform(df['avaliacao_cliente'].values.reshape(len(df), 1))

# %%
df.avaliacao_cliente.sample(10)
# Out:
# 7085    -1.408469
# 9166     0.715811
# 9126    -1.408469
# 9835     0.007718
# 7346    -0.700376
# 5187     1.423904
# 8350    -0.700376
# 3342     0.715811
# 6529     0.007718
# 10098   -0.700376
# Name: avaliacao_cliente, dtype: float64

# %%
df['compras_anteriores'] = StandardScaler().fit_transform(df['compras_anteriores'].values.reshape(len(df), 1))

# %%
df.compras_anteriores.sample(10)
# Out:
# 9704    1.192105
# 6544    0.416201
# 2000   -0.359702
# 2157   -0.359702
# 211    -0.359702
# 605     1.192105
# 3019   -1.135605
# 6707   -1.135605
# 5822   -1.135605
# 6471   -0.359702
# Name: compras_anteriores, dtype: float64

# %%
df.head()
# Out:
#    modo_envio  numero_chamadas_cliente  avaliacao_cliente  custo_produto  \
# 0           1                -0.057348          -0.700376       0.378505
# 1           1                -0.057348           1.423904       0.560748
# 2           1                -1.803706          -0.700376       0.406542
# 3           1                -0.930527           0.007718       0.373832
# 4           1                -1.803706          -0.700376       0.411215
#
#    compras_anteriores  prioridade_produto  genero  desconto  peso_gramas  \
# 0           -0.359702                   1       0  2.099353     0.033893
# 1           -1.135605                   1       1  3.099936     0.304894
# 2            0.416201                   1       1  2.366175     0.346676
# 3            0.416201                   2       1 -0.168635     0.025712
# 4           -0.359702                   2       0  2.232764     0.216654
#
#    entregue_no_prazo  ...  \
# 0                  1  ...
# 1                  1  ...
# 2                  1  ...
# 3                  1  ...
# 4                  1  ...
#
#    performance_modo_envio_Atraso Problemático na Entrega Por Navio  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    performance_modo_envio_Atraso Tolerável na Entrega Por Aviao  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    performance_modo_envio_Atraso Tolerável na Entrega Por Caminhao  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    performance_modo_envio_Atraso Tolerável na Entrega Por Navio  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    performance_modo_envio_Não Houve Atraso  \
# 0                                     True
# 1                                     True
# 2                                     True
# 3                                     True
# 4                                     True
#
#    faixa_desconto_Desconto Abaixo da Media  \
# 0                                    False
# 1                                    False
# 2                                    False
# 3                                     True
# 4                                    False
#
#    faixa_desconto_Desconto Acima da Media  \
# 0                                    True
# 1                                    True
# 2                                    True
# 3                                   False
# 4                                    True
#
#    performance_faixa_desconto_Atraso na Entrega com Desconto Abaixo da Media  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    performance_faixa_desconto_Entrega no Prazo com Desconto Abaixo da Media  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                               True
# 4                                              False
#
#    performance_faixa_desconto_Entrega no Prazo com Desconto Acima da Media
# 0                                               True
# 1                                               True
# 2                                               True
# 3                                              False
# 4                                               True
#
# [5 rows x 34 columns]

# %%
df.to_csv(file_path + 'dataset_final.csv', sep = ',', encoding = 'utf-8')

# %% [markdown]
# # Fim
